# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Roy Fowler**
# Insurance Office Manager, looking to be a data scientist for insurance or retail company

# %% [markdown]
# *I am interested in data science because I see it as the future for companies, and the best way to help the public. Using data science, everything can be more personalized, making things more affordable for the public, and profitable for the companies. I feel called to do everything I can to help that vision come to fruition, so that overall everybody can win.*

# %% [markdown]
# ### The code below performs basic addittion using the variables x,y, and z to perform the funciton z=x+y

# %%
x=4
y=6
z=x+y
print(z)
# Out:
# 10

# %% [markdown]
# |x|y|z|
# |---|---|---
# |1|2|3|
# |2|2|4|
# |4|6|10|
#
# 1. The inputs for x and y can be `any number` you'd like.
# - 1
# - 1000
# - 1000000
# - 347659812698589627
# 2. z will provide an output for any combination of x and y, as long as `valid digits` are used!
# 3. words will ~~work~~ `NOT` work.
